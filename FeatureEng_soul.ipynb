# %%
import pandas as pd
import numpy as np

# visualization
import seaborn as sns #설치 필요
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cd /Users/Soul.C/data/instacart
# Out:
# /Users/Soul.C/data/instacart

# %%
aisles = pd.read_csv('aisles.csv', engine='c')
print('Total aisles: {}'.format(aisles.shape[0]))      
aisles.head(10)
aisles.tail(5)
aisles
# Out:
# Total aisles: 134
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>aisle_id</th>
#       <th>aisle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>129</th>
#       <td>130</td>
#       <td>hot cereal pancake mixes</td>
#     </tr>
#     <tr>
#       <th>130</th>
#       <td>131</td>
#       <td>dry pasta</td>
#     </tr>
#     <tr>
#       <th>131</th>
#       <td>132</td>
#       <td>beauty</td>
#     </tr>
#     <tr>
#       <th>132</th>
#       <td>133</td>
#       <td>muscles joints pain relief</td>
#     </tr>
#     <tr>
#       <th>133</th>
#       <td>134</td>
#       <td>specialty wines champagnes</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
departments = pd.read_csv('departments.csv', engine='c')
print('Total departments: {}'.format(departments.shape[0]))
departments.head()
# Out:
# Total departments: 21
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>department_id</th>
#       <th>department</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>frozen</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>other</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>bakery</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>produce</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>alcohol</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
products = pd.read_csv('products.csv', engine='c')
print('Total products: {}'.format(products.shape[0]))
products.head(5)
# Out:
# Total products: 49688
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id</th>
#       <th>product_name</th>
#       <th>aisle_id</th>
#       <th>department_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Chocolate Sandwich Cookies</td>
#       <td>61</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>All-Seasons Salt</td>
#       <td>104</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Robust Golden Unsweetened Oolong Tea</td>
#       <td>94</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %%
goods = pd.merge(left=pd.merge(left=products, right=departments, how='left'), 
                 right=aisles, how='left')
goods.shape
# Out:
# (49688, 6)

# %%
goods.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id</th>
#       <th>product_name</th>
#       <th>aisle_id</th>
#       <th>department_id</th>
#       <th>department</th>
#       <th>aisle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Chocolate Sandwich Cookies</td>
#       <td>61</td>
#       <td>19</td>
#       <td>snacks</td>
#       <td>cookies cakes</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>All-Seasons Salt</td>
#       <td>104</td>
#       <td>13</td>
#       <td>pantry</td>
#       <td>spices seasonings</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
# ...

# %%
plt.figure(figsize=(12, 5))
goods.groupby(['department']).count()['product_id'].copy()\
.sort_values(ascending=False).plot(kind='bar', 
                                   #figsize=(12, 5), 
                                   title='Departments: Product #')

# %%
op_train = pd.read_csv('order_products__train.csv', engine='c')
print('Total ordered products(train): {}'.format(op_train.shape[0]))
op_train.head(5)
# Out:
# Total ordered products(train): 1384617
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>product_id</th>
#       <th>add_to_cart_order</th>
#       <th>reordered</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>49302</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>11109</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>10246</td>
#       <td>3</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>49683</td>
# ...

# %%
op_prior = pd.read_csv('order_products__prior.csv', engine='c')
print('Total ordered products(prior): {}'.format(op_prior.shape[0]))
op_prior.head()
# Out:
# Total ordered products(prior): 32434489
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>product_id</th>
#       <th>add_to_cart_order</th>
#       <th>reordered</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>33120</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>28985</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>9327</td>
#       <td>3</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>45918</td>
# ...

# %%
orders = pd.read_csv('orders.csv', engine='c',)
print('Total orders: {}'.format(orders.shape[0]))
orders.sort_values(['order_id']).head(5)
# Out:
# Total orders: 3421083
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>user_id</th>
#       <th>eval_set</th>
#       <th>order_number</th>
#       <th>order_dow</th>
#       <th>order_hour_of_day</th>
#       <th>days_since_prior_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1868044</th>
#       <td>1</td>
#       <td>112108</td>
#       <td>train</td>
#       <td>4</td>
#       <td>4</td>
#       <td>10</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>3355525</th>
#       <td>2</td>
#       <td>202279</td>
#       <td>prior</td>
#       <td>3</td>
#       <td>5</td>
#       <td>9</td>
#       <td>8.0</td>
# ...

# %%
train = pd.merge(left=op_prior,right=orders,how='left',on='order_id', left_index=True)

# %%
val = pd.merge(left=op_train,right=orders,how='left',on='order_id')

# %%
# order_details_trains = pd.merge(left=order_details_train,
#                 right=goods[['product_id', 
#                              'aisle_id', 
#                              'department_id']],
#                 how='left',
#                 on='product_id'
# )

# %%
# order_details_trains = pd.merge(left=order_details_prior,
#                 right=goods[['product_id', 
#                              'aisle_id', 
#                              'department_id']],
#                 how='left',
#                 on='product_id'
# )

# %%
train.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>user_id</th>
#       <th>product_id</th>
#       <th>add_to_cart_order</th>
#       <th>order_number</th>
#       <th>order_dow</th>
#       <th>order_hour_of_day</th>
#       <th>days_since_prior_order</th>
#       <th>reordered</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3355525</th>
#       <td>2</td>
#       <td>202279</td>
#       <td>33120</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3355525</th>
#       <td>2</td>
#       <td>202279</td>
# ...

# %%
train.columns.tolist()
# Out:
# ['order_id',
#  'product_id',
#  'add_to_cart_order',
#  'reordered',
#  'user_id',
#  'eval_set',
#  'order_number',
#  'order_dow',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
#val.drop('eval_set',axis=1, inplace=True)
train.drop('eval_set', axis=1, inplace=True)

# %%
test = orders[orders.eval_set == 'test']
test.shape
# Out:
# (75000, 7)

# %%
#cols = train.columns.tolist()
#실행하면 이름 바뀐 컬럼의 값이 다 NaN됨 ;; 
"""
cols = ['order_id',
        'user_id',
        'product_id',
         'add_to_cart_order',
         'order_number',
         'order_dow',
         'order_hour_of_day',
         'days_since_prior_order',
         'reordered']
train = train.reindex(columns=cols)
"""

# %%
train.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>product_id</th>
#       <th>add_to_cart_order</th>
#       <th>reordered</th>
#       <th>user_id</th>
#       <th>order_number</th>
#       <th>order_dow</th>
#       <th>order_hour_of_day</th>
#       <th>days_since_prior_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3355525</th>
#       <td>2</td>
#       <td>33120</td>
#       <td>1</td>
#       <td>1</td>
#       <td>202279</td>
#       <td>3</td>
#       <td>5</td>
#       <td>9</td>
#       <td>8.0</td>
#     </tr>
#     <tr>
#       <th>3355525</th>
#       <td>2</td>
#       <td>28985</td>
#       <td>2</td>
# ...

# %%
train.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d1e6dafc79e> in <module>()
# ----> 1 train.columns.tolist()
#
# NameError: name 'train' is not defined

# %%
train = train.rename( index=str, columns={'add_to_cart_order':'add_order', 'order_hour_of_day':'order_hr','days_since_prior_order':'days_since'})

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
prd_cnt = train['product_id'].value_counts(normalize=True).reset_index().sort_values('product_id',ascending=False)
# prd_count
#pcnt_rate = pd.DataFrame(train.product_id.value_counts(normalize=True))
#cnt = order_products_prior_df['product_name'].value_counts().reset_index().head(20)
#prd_cnt = ['product_id', 'frequency_count']
prd_cnt
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>product_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24852</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>13176</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>21137</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>21903</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>47209</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>47766</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>6</th>
# ...

# %%
prd_cnt = train.groupby('product_id').count()[['order_id']]
prd_cnt.columns = ['prd_cnt']
train1 = train.merge(prd_cnt, left_on='product_id', right_index=True)
train1.head()
# prd_cnt[['product_id','counts']].groupby(['product_id'],as_index=False).mean().sort_values(by='counts',ascending=False)
# Out:
#       order_id  user_id  product_id  add_to_cart_order  order_number  \
# 0            2   202279       33120                  1             3
# 237         26   153404       33120                  5             2
# 1084       120    23750       33120                 13            11
# 3039       327    58707       33120                  5            21
# 3709       390   166654       33120                 28            48
#
#       order_dow  order_hour_of_day  days_since_prior_order  reordered  prd_cnt
# 0             5                  9                     8.0          1    19400
# 237           0                 16                     7.0          0    19400
# 1084          6                  8                    10.0          0    19400
# 3039          6                  9                     8.0          1    19400
# 3709          0                 12                     9.0          1    19400

# %%
#가입한지 오래된 유저들 
oldUsers = train[['user_id','days_since_prior_order']].groupby(['user_id'],as_index=False).sum().sort_values(by='days_since_prior_order',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f513bee6e8d1> in <module>()
#       1 #가입한지 오래된 유저들
# ----> 2 oldUsers = train[['user_id','days_since_prior_order']].groupby(['user_id'],as_index=False).sum().sort_values(by='days_since_prior_order',ascending=False)
#
# NameError: name 'train' is not defined

# %%
train1 = pd.merge(left=train1, right=oldUsers, how='left', on='user_id')

# train1.rename(index=str, columns={'days_since_prior_order_y':'joined_d'})
train1.head()
# Out:
#    order_id  user_id  product_id  add_to_cart_order  order_number  order_dow  \
# 0         2   202279       33120                  1             3          5
# 1        26   153404       33120                  5             2          0
# 2       120    23750       33120                 13            11          6
# 3       327    58707       33120                  5            21          6
# 4       390   166654       33120                 28            48          0
#
#    order_hour_of_day  days_since_prior_order_x  reordered  prd_cnt  \
# 0                  9                       8.0          1    19400
# 1                 16                       7.0          0    19400
# 2                  8                      10.0          0    19400
# 3                  9                       8.0          1    19400
# 4                 12                       9.0          1    19400
#
#    days_since_prior_order_y
# 0                    1749.0
# 1                    4064.0
# ...

# %%
# del train1['days_since_prior_order_y']
train1.rename(index=str, columns={'days_since_prior_order':'joined'})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-965ebf1233b8> in <module>()
#       1 # del train1['days_since_prior_order_y']
# ----> 2 train1.rename(index=str, columns={'days_since_prior_order':'joined'})
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, index, columns, **kwargs)
#    2842     def rename(self, index=None, columns=None, **kwargs):
#    2843         return super(DataFrame, self).rename(index=index, columns=columns,
# -> 2844                                              **kwargs)
#    2845
#    2846     @Appender(_shared_docs['fillna'] % _shared_doc_kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in rename(self, *args, **kwargs)
#     723                 level = self.axes[axis]._get_level_number(level)
# ...

# %%
#
join_r = train1[['user_id','days_since_prior_order_y','reordered']].groupby(['user_id'],as_index=False).mean().sort_values(by='reordered',ascending=False)

# %%
(join_r['days_since_prior_order_y']).corr(join_r['reordered'])
# Out:
# 0.52656239221511847

# %%
royal_r = train1[['user_id','order_number','reordered']].groupby(['user_id'],as_index=False).mean().sort_values(by='reordered',ascending=False)
royal_r.head()
# Out:
#         user_id  order_number  reordered
# 99752     99753     50.010471   0.989529
# 82413     82414     48.401869   0.981308
# 107527   107528     27.490385   0.980769
# 17996     17997     48.866667   0.979310
# 5587       5588     48.508772   0.978857

# %%
(royal_r['order_number']).corr(royal_r['reordered'])
# Out:
# 0.63483303634479871

# %%
royal_r['old_royal'] = royal_r['order_number']*join_r['days_since_prior_order_y']
(royal_r['old_royal']).corr(royal_r['reordered'])
# Out:
# 0.54435773473759785

# %%
plt.bar(train['order_hr'], train['']
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>user_id</th>
#       <th>product_id</th>
#       <th>add_order</th>
#       <th>order_number</th>
#       <th>order_dow</th>
#       <th>order_hr</th>
#       <th>days_since</th>
#       <th>reordered</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>202279</td>
#       <td>33120</td>
#       <td>1</td>
#       <td>3</td>
#       <td>5</td>
#       <td>9</td>
#       <td>8.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>202279</td>
#       <td>28985</td>
#       <td>2</td>
#       <td>3</td>
# ...

# %%
#시간 별 주문 건수 
plt.figure(figsize=(12,8))
sns.countplot(x="order_hour_of_day", data=orders_df, color=color[1])
plt.ylabel('Count', fontsize=12)
plt.xlabel('Hour of day', fontsize=12)
plt.xticks(rotation='vertical')
plt.title("Frequency of order by hour of day", fontsize=15)
plt.show()

# %%
from functools import partial

# merge train and prior together iteratively, to fit into 8GB kernel RAM
# split df indexes into parts
indexes = np.linspace(0, len(op_prior), num=10, dtype=np.int32)

# initialize it with train dataset
order_details = pd.merge(
                left=op_train,
                 right=orders, 
                 how='left', 
                 on='order_id'
        ).apply(partial(pd.to_numeric, errors='ignore', downcast='integer'))

# add order hierarchy
order_details = pd.merge(
                left=order_details,
                right=goods[['product_id', 
                             'aisle_id', 
                             'department_id']].apply(partial(pd.to_numeric, 
                                                             errors='ignore', 
                                                             downcast='integer')),
                how='left',
                on='product_id'
)

print(order_details.shape, op_train.shape)

# delete (redundant now) dataframes
del op_train

order_details.head()

# %%
#평균 days since prior order
avg_days = train[['days_since_prior_order','user_id','reordered']].groupby(['user_id'],as_index=False).mean().\
    sort_values(by='reordered',ascending=False)
avg

# %%
avg_days.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-a35a01321ed7> in <module>()
# ----> 1 avg_days.plot(kind='bar')
#
# /Users/Soul.C/anaconda/envs/py36/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# ...

# %% [markdown]
# ### us_prd_cnt
# ######  한 유저가 주문한 제품 별 개수

# %%
up_cnt = train.groupby(['user_id', 'product_id']).size().reset_index(name='us_prd_cnt')

# %%
up_cnt.head(50)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>product_id</th>
#       <th>us_prd_cnt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>196</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>10258</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>10326</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>12427</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>13032</td>
#       <td>3</td>
#     </tr>
#     <tr>
# ...

# %%
#유저 별로 구매한 총 제품 수 구하기 
user_cnt = train.groupby(['user_id']).size().reset_index(name='us_cnt')
user_cnt.head(50)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>us_cnt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>195</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>206</td>
# ...

# %%
us_prd = pd.merge(left=up_cnt, right=user_cnt, on='user_id')
us_prd.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>product_id</th>
#       <th>us_prd_cnt</th>
#       <th>us_cnt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>196</td>
#       <td>10</td>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>10258</td>
#       <td>9</td>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>10326</td>
#       <td>1</td>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>12427</td>
#       <td>10</td>
#       <td>59</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### us_prd_rate
# ###### 한 유저가 총 주문한 양 대비 각 제품의 비율 (총100중에 몇퍼가 해당 제품인가)

# %%
#한 유저가 총 주문한 양 대비 각 제품의 비율 (총100중에 몇퍼가 해당 제품인가)
us_prd['us_prd_rate'] = (us_prd['us_prd_cnt'])/(us_prd['us_cnt'])
us_prd.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>product_id</th>
#       <th>us_prd_cnt</th>
#       <th>us_cnt</th>
#       <th>us_prd_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>196</td>
#       <td>10</td>
#       <td>59</td>
#       <td>0.17</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>10258</td>
#       <td>9</td>
#       <td>59</td>
#       <td>0.15</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>10326</td>
#       <td>1</td>
#       <td>59</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %%
train1 = train[['user_id','product_id','order_number']]

# %%
us_prd_merged = pd.merge(left=us_prd, right=train1, on=['user_id','product_id'])

# %%
us_prd_merged.head(15)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>product_id</th>
#       <th>us_prd_cnt</th>
#       <th>us_cnt</th>
#       <th>us_prd_rate</th>
#       <th>order_number</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>196</td>
#       <td>10</td>
#       <td>59</td>
#       <td>0.17</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>196</td>
#       <td>10</td>
#       <td>59</td>
#       <td>0.17</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>196</td>
#       <td>10</td>
#       <td>59</td>
# ...

# %% [markdown]
# #### us_prd_longago
# ###### 한 유저가 각 제품을 마지막으로 사고 나서 몇 번의 주문이 지났는가, 얼마나 오래 되었는가
# ###### (10번의 주문을 한 유저가 바나나를 가장 최근에 산 주문이 7번째 주문이라면 값은 3, 숫자 클수록 주문한지 오래됨)

# %%
#한 유저가 각 제품을 마지막으로 산 주문은 몇 번째 주문이었나 구하기
us_prd_max = us_prd_merged.groupby(['user_id','product_id'])['order_number'].max().reset_index(name='us_prd_last_order')

# %%
#각 유저당 총 몇 번의 주문을 했는가를 한 표에 가져다 붙이기 
a = train.groupby(['user_id'])['order_number'].max().reset_index(name='us_last_order')
us_prd = pd.merge(us_prd_max, a, on='user_id')
us_prd.head(20)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>product_id</th>
#       <th>us_prd_last_order</th>
#       <th>us_last_order_x</th>
#       <th>us_last_order_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>196</td>
#       <td>10</td>
#       <td>1.00</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>10258</td>
#       <td>10</td>
#       <td>2.00</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>10326</td>
#       <td>5</td>
#       <td>3.00</td>
#       <td>10</td>
#     </tr>
#     <tr>
# ...

# %%
#컬럼이름 정리 
#us_prd.drop('us_last_order_x',axis=1,inplace=True)
us_prd.rename(index=str, columns={'us_last_order_y':'us_last_order'}, inplace=True)

# %%
us_prd['us_prd_longago'] = (us_prd['us_last_order']) - (us_prd['us_prd_last_order'])

# %%
#값 확인해 보면 가장 최근 주문까지 해당 제품을 산 경우 값이 0 이 됨. 1을 더해줄까 ?상관없나 ?
us_prd.head(30)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>product_id</th>
#       <th>us_prd_last_order</th>
#       <th>us_last_order</th>
#       <th>us_prd_longago</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>196</td>
#       <td>10</td>
#       <td>10</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>10258</td>
#       <td>10</td>
#       <td>10</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>10326</td>
#       <td>5</td>
#       <td>10</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %% [markdown]
# #### us_prd_constancy
# ###### 한 유저가 어떤 제품을 처음으로 주문하고 나서, 이후 주문들에 얼마나 꾸준히 재구매해왔는가 : 그 제품을 꾸준히 사왔을 수록 값이 큼
# ###### (2번 째 주문에 바나나를 처음 사기 시작한 유저가 10번의 주문을 하는 동안 바나나를 3번 샀다면 3/10-2+1 = 1/3)

# %%
us_prd_merged2 = pd.merge(us_prd_merged, us_prd, on=['user_id','product_id'])

# %%
us_prd_merged2.tail(30)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>product_id</th>
#       <th>us_prd_cnt</th>
#       <th>us_cnt</th>
#       <th>us_prd_rate</th>
#       <th>order_number</th>
#       <th>us_prd_last_order</th>
#       <th>us_last_order</th>
#       <th>us_prd_longago</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>32434459</th>
#       <td>206209</td>
#       <td>38167</td>
#       <td>4</td>
#       <td>129</td>
#       <td>0.03</td>
#       <td>12</td>
#       <td>12</td>
#       <td>13</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>32434460</th>
#       <td>206209</td>
#       <td>38167</td>
#       <td>4</td>
# ...

# %%
#한 유저가 각 제품을 처음으로 산 주문은 몇 번째 주문이었나 구하기
us_prd_merged2['us_prd_first_order'] = us_prd_merged.groupby(['user_id','product_id'])['order_number'].min()
us_prd_merged2.tail(20)

# %%
us_prd_merged2['us_prd_constancy'] = us_prd_merged2['us_prd_cnt'] /  (us_prd_merged2['us_prd_cnt'] -us_prd_merged2['us_prd_first_order']
